# %%
import os
import csv
import pandas as pd
import numpy as np
import ssl
import smtplib
import request
from dotenv import load_dotenv
from tabulate import tabulate
from datetime import datetime
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
from facebook_business.api import FacebookAdsApi
from facebook_business.adobjects.adaccount import AdAccount

# Load environement variables
load_dotenv()

# Getting Acces ID from env_vars
my_app_id = os.environ.get("MY_APP_ID")
my_app_secret = os.environ.get("MY_APP_SECRET")
my_access_token = os.environ.get("MY_ACCESS_TOKEN")


# Initialitiong connection with Facebook
FacebookAdsApi.init(my_app_id, my_app_secret, my_access_token)

# Connecting to accounts
laSalle_account = AdAccount(os.environ.get("LASALLE_ADACCOUNT"))

# Seting-Up my requests
params = {
    'date_preset': "last_week_mon_sun",
    "level": "campaign",
    'time_increment': "1"
}

fields = ["campaign_name", "reach", "clicks", "spend"]

# Requesting insights
laSalle_insights = laSalle_account.get_insights(params=params, fields=fields)

# Transform insights into a list of dict
laSalle_insights = [dict(x) for x in laSalle_insights]

# Print result
print(laSalle_insights)
# Out:
# [{'id': None, 'campaign_name': 'CL - Campagne permanente - Boost post - PO004623', 'reach': '18251', 'clicks': '2282', 'spend': '172.24', 'date_start': '2019-04-01', 'date_stop': '2019-04-01'}, {'id': None, 'campaign_name': 'eLearning - Conversion - Budget Optimization - PO000000', 'reach': '5898', 'clicks': '73', 'spend': '97.93', 'date_start': '2019-04-01', 'date_stop': '2019-04-01'}, {'id': None, 'campaign_name': 'CLM - Conversion - Discussion DEC Phase 2 - Mars 2019 - FR - PO005153', 'reach': '7588', 'clicks': '61', 'spend': '65.08', 'date_start': '2019-04-01', 'date_stop': '2019-04-01'}, {'id': None, 'campaign_name': 'CLM - Conversion - Discussion DEC Phase 2 - Mars 2019 - EN - PO005153', 'reach': '7744', 'clicks': '35', 'spend': '51.4', 'date_start': '2019-04-01', 'date_stop': '2019-04-01'}, {'id': None, 'campaign_name': 'CLM - Rentrée été - Cuisine - EN/FR - PO005283', 'reach': '4090', 'clicks': '17', 'spend': '23.24', 'date_start': '2019-04-01', 'date_stop': '2019-04-01'}, {'id': None, 'campaign_name': 'CLM - Rentrée été 2019 - Mtl - FR - PO005283', 'reach': '4911', 'clicks': '50', 'spend': '60.2', 'date_start': '2019-04-01', 'date_stop': '2019-04-01'}, {'id': None, 'campaign_name': 'CLM - Rentrée été 2019 - Mtl - EN - PO005283', 'reach': '5161', 'clicks': '60', 'spend': '60.52', 'date_start': '2019-04-01', 'date_stop': '2019-04-01'}, {'id': None, 'campaign_name': 'CLM - Rentrée été 2019 - Laval - FR - PO005283', 'reach': '1901', 'clicks': '23', 'spend': '23.36', 'date_start': '2019-04-01', 'date_stop': '2019-04-01'}, {'id': None, 'campaign_name': 'CLM - Rentrée été 2019 - Laval - EN - PO005283', 'reach': '1295', 'clicks': '9', 'spend': '15.16', 'date_start': '2019-04-01', 'date_stop': '2019-04-01'}, {'id': None, 'campaign_name': 'eLearning - Rentrée été 2019 - FR - PO005154', 'reach': '6616', 'clicks': '102', 'spend': '106.6', 'date_start': '2019-04-01', 'date_stop': '2019-04-01'}, {'id': None, 'campaign_name': 'eLearning - Rentrée été 2019 - EN - PO005154', 'reach': '4501', 'clicks': '29', 'spend': '60.43', 'date_start': '2019-04-01', 'date_stop': '2019-04-01'}, {'id': None, 'campaign_name': 'eLearning- Webinaires - Avril 2019 - EN/FR - PO005154', 'reach': '8890', 'clicks': '195', 'spend': '193.37', 'date_start': '2019-04-01', 'date_stop': '2019-04-01'}, {'id': None, 'campaign_name': 'CL - Campagne permanente - Boost post - PO004623', 'reach': '25677', 'clicks': '4329', 'spend': '173.45', 'date_start': '2019-04-02', 'date_stop': '2019-04-02'}, {'id': None, 'campaign_name': 'eLearning - Conversion - Budget Optimization - PO000000', 'reach': '7103', 'clicks': '82', 'spend': '101.44', 'date_start': '2019-04-02', 'date_stop': '2019-04-02'}, {'id': None, 'campaign_name': 'CLM - Conversion - Discussion DEC Phase 2 - Mars 2019 - FR - PO005153', 'reach': '6106', 'clicks': '61', 'spend': '63.98', 'date_start': '2019-04-02', 'date_stop': '2019-04-02'}, {'id': None, 'campaign_name': 'CLM - Conversion - Discussion DEC Phase 2 - Mars 2019 - EN - PO005153', 'reach': '9583', 'clicks': '43', 'spend': '51.38', 'date_start': '2019-04-02', 'date_stop': '2019-04-02'}, {'id': None, 'campaign_name': 'CLM - Rentrée été - Cuisine - EN/FR - PO005283', 'reach': '4324', 'clicks': '18', 'spend': '22.97', 'date_start': '2019-04-02', 'date_stop': '2019-04-02'}, {'id': None, 'campaign_name': 'CLM - Rentrée été 2019 - Mtl - FR - PO005283', 'reach': '5036', 'clicks': '66', 'spend': '60.46', 'date_start': '2019-04-02', 'date_stop': '2019-04-02'}, {'id': None, 'campaign_name': 'CLM - Rentrée été 2019 - Mtl - EN - PO005283', 'reach': '5836', 'clicks': '58', 'spend': '59.88', 'date_start': '2019-04-02', 'date_stop': '2019-04-02'}, {'id': None, 'campaign_name': 'CLM - Rentrée été 2019 - Laval - FR - PO005283', 'reach': '1841', 'clicks': '18', 'spend': '22.87', 'date_start': '2019-04-02', 'date_stop': '2019-04-02'}, {'id': None, 'campaign_name': 'CLM - Rentrée été 2019 - Laval - EN - PO005283', 'reach': '1385', 'clicks': '11', 'spend': '14.68', 'date_star ...

# %%
df = pd.DataFrame.from_dict(laSalle_insights)
df = df.assign(Time=pd.to_datetime(df.date_stop)).drop('date_start', axis='columns').drop('date_stop', axis='columns')

# Identify schools and boost
df['campaign_name'] = df['campaign_name'].str.replace("CLM", "laSalle").str.replace("CL", "Boost").str.replace("eLearning", "eLearning")

# Create school column
df['school'] = df["campaign_name"].str.split("-", n=1, expand=True)[0]
df['school'] = df['school'].str.replace(" ", "")

# Intermediate state to get a clean campaign column
df["campaign_rename"] = df["campaign_name"].str.split("-", n=1, expand=True)[1]

# Create PO column
df["po"] = df["campaign_rename"].str.rsplit("-", n=1, expand=True)[1]
df["po"] = df["po"].str.replace(" ", "")

# Create a clean campaign column
df["campaign"] = df["campaign_rename"].str.rsplit("-", n=1, expand=True)[0]

# Get rid of dirty columns
df = df.drop('campaign_name', axis='columns').drop('campaign_rename', axis='columns')

# Reorder columns
clean = df[["campaign", "school", "po", "Time", "spend", "reach","clicks"]]
clean
# Out:
#                                              campaign     school        po  \
# 0                   Campagne permanente - Boost post       Boost  PO004623
# 1                   Conversion - Budget Optimization   eLearning  PO000000
# 2    Conversion - Discussion DEC Phase 2 - Mars 20...    laSalle  PO005153
# 3    Conversion - Discussion DEC Phase 2 - Mars 20...    laSalle  PO005153
# 4                      Rentrée été - Cuisine - EN/FR     laSalle  PO005283
# 5                        Rentrée été 2019 - Mtl - FR     laSalle  PO005283
# 6                        Rentrée été 2019 - Mtl - EN     laSalle  PO005283
# 7                      Rentrée été 2019 - Laval - FR     laSalle  PO005283
# 8                      Rentrée été 2019 - Laval - EN     laSalle  PO005283
# 9                              Rentrée été 2019 - FR   eLearning  PO005154
# 10                             Rentrée été 2019 - EN   eLearning  PO005154
# 11                   Webinaires - Avril 2019 - EN/FR   eLearning  PO005154
# 12                  Campagne permanente - Boost post       Boost  PO004623
# 13                  Conversion - Budget Optimization   eLearning  PO000000
# 14   Conversion - Discussion DEC Phase 2 - Mars 20...    laSalle  PO005153
# 15   Conversion - Discussion DEC Phase 2 - Mars 20...    laSalle  PO005153
# 16                     Rentrée été - Cuisine - EN/FR     laSalle  PO005283
# 17                       Rentrée été 2019 - Mtl - FR     laSalle  PO005283
# 18                       Rentrée été 2019 - Mtl - EN     laSalle  PO005283
# 19                     Rentrée été 2019 - Laval - FR     laSalle  PO005283
# 20                     Rentrée été 2019 - Laval - EN     laSalle  PO005283
# 21                             Rentrée été 2019 - FR   eLearning  PO005154
# 22                             Rentrée été 2019 - EN   eLearning  PO005154
# 23                   Webinaires - Avril 2019 - EN/FR   eLearning  PO005154
# 24                  Campagne permanente - Boost post       Boost  PO004623
# 25                  Conversion - Budget Optimization   eLearning  PO000000
# 26   Conversion - Discussion DEC Phase 2 - Mars 20...    laSalle  PO005153
# 27   Conversion - Discussion DEC Phase 2 - Mars 20...    laSalle  PO005153
# 28                     Rentrée été - Cuisine - EN/FR     laSalle  PO005283
# 29                       Rentrée été 2019 - Mtl - FR     laSalle  PO005283
# ..                                                ...        ...       ...
# 54                     Rentrée été 2019 - Laval - FR     laSalle  PO005283
# 55                     Rentrée été 2019 - Laval - EN     laSalle  PO005283
# 56                             Rentrée été 2019 - FR   eLearning  PO005154
# 57                             Rentrée été 2019 - EN   eLearning  PO005154
# 58                   Webinaires - Avril 2019 - EN/FR   eLearning  PO005154
# 59                       Signature 2019 -MTL - FR/En     laSalle  PO005379
# 60                  Conversion - Budget Optimization   eLearning  PO000000
# 61   Conversion - Discussion DEC Phase 2 - Mars 20...    laSalle  PO005153
# 62   Conversion - Discussion DEC Phase 2 - Mars 20...    laSalle  PO005153
# 63                     Rentrée été - Cuisine - EN/FR     laSalle  PO005283
# 64                       Rentrée été 2019 - Mtl - FR     laSalle  PO005283
# 65                       Rentrée été 2019 - Mtl - EN     laSalle  PO005283
# 66                     Rentrée été 2019 - Laval - FR     laSalle  PO005283
# 67                     Rentrée été 2019 - Laval - EN     laSalle  PO005283
# 68                             Rentrée été 2019 - FR   eLearning  PO005154
# 69                             Rentrée été 2019 - EN   eLearning  PO005154
# 70                   Webinaires - Avril 2019 - EN/FR   eLearning  PO005154
# 71                       Signature 2019 -MTL - FR/En     laSalle  PO005379
# 72                  Conversion - Budget Optimization   eLearning  PO000000
# 73   Conversion - Discussion DEC Phase 2 - Mars 20...    laSalle  PO005153
# 74   Conversion - Discussion DEC Phase 2 - Mars 20...    laSalle  PO005153
# 75                     Rentrée été - Cuisine - EN/FR     laSalle  PO005283
# 76                       Rentrée été 2019 - Mtl - FR     laSalle  PO005283
# 77                       Rentrée été 2019 - Mtl - EN     laSalle  PO005283
# 78                     Rentrée été 2019 - Laval - FR     laSalle  PO005283
# 79                     Rentrée été 2019 - Laval - EN     laSalle  PO005283
# 80                             Rentrée été 2019 - FR   eLearning  PO005154
# 81                             Rentrée été 2019 - EN   eLearning  PO005154
# 82                   Webinaires - Avril 2019 - EN/FR   eLearning  PO005154
# 83                       Signature 2019 -MTL - FR/En     laSalle  PO005379
#
#          Time   spend  reach clicks
# 0  2019-04-01  172.24  18251   2282
# 1  2019-04-01   97.93   5898     73
# 2  2019-04-01   65.08   7588     61
# 3  2019-04-01    51.4   7744     35
# 4  2019-04-01   23.24   4090     17
# 5  2019-04-01    60.2   4911     50
# 6  2019-04-01   60.52   5161     60
# 7  2019-04-01   23.36   1901     23
# 8  2019-04-01   15.16   1295      9
# 9  2019-04-01   106.6   6616    102
# 10 2019-04-01   60.43   4501     29
# 11 2019-04-01  193.37   8890    195
# 12 2019-04-02  173.45  25677   4329
# 13 2019-04-02  101.44   7103     82
# 14 2019-04-02   63.98   6106     61
# 15 2019-04-02   51.38   9583     43
# 16 2019-04-02   22.97   4324     18
# 17 2019-04-02   60.46   5036     66
# 18 2019-04-02   59.88   5836     58
# 19 2019-04-02   22.87   1841     18
# 20 2019-04-02   14.68   1385     11
# 21 2019-04-02  104.09   6654     98
# 22 2019-04-02   58.75   4289     25
# 23 2019-04-02  277.09  11380    287
# 24 2019-04-03   94.74  16679   2971
# 25 2019-04-03   96.81   7118     72
# 26 2019-04-03   60.22   7664     77
# 27 2019-04-03   48.54  10612     37
# 28 2019-04-03   22.15   3686     17
# 29 2019-04-03   57.25   4921     52
# ..        ...     ...    ...    ...
# 54 2019-04-05    22.2   1980     22
# 55 2019-04-05   14.61   1331      4
# 56 2019-04-05  106.01   7026    111
# 57 2019-04-05   60.41   4356     22
# 58 2019-04-05   211.4   7792    129
# 59 2019-04-05   16.09    909      7
# 60 2019-04-06  111.43   8195     84
# 61 2019-04-06   65.93   6620     49
# 62 2019-04-06   53.83  11012     56
# 63 2019-04-06   24.12   3619     18
# 64 2019-04-06      63   4698     56
# 65 2019-04-06   63.99   4973     49
# 66 2019-04-06    24.7   1906     16
# 67 2019-04-06    16.6   1364      3
# 68 2019-04-06  116.17   7042    109
# 69 2019-04-06    65.1   4441     34
# 70 2019-04-06  239.98   8834    126
# 71 2019-04-06   17.62    969      5
# 72 2019-04-07   96.21   6193     53
# 73 2019-04-07   62.29   8606     54
# 74 2019-04-07   51.08  10632     45
# 75 2019-04-07   23.15   3608     20
# 76 2019-04-07    60.4   4965     66
# 77 2019-04-07   61.02   5350     63
# 78 2019-04-07   23.27   1885     15
# 79 2019-04-07   15.26   1226     10
# 80 2019-04-07  106.11   6218     88
# 81 2019-04-07   60.44   4370     26
# 82 2019-04-07  267.93   9824    163
# 83 2019-04-07   17.94   1046      0
#
# [84 rows x 7 columns]

# %%
# Make sure spend is the right data type
df.spend = df.spend.astype(float)

# Create pivot table to extract some KPI
pivot = pd.pivot_table(df, values='spend', index=['po'], columns=['school'], aggfunc=np.sum, fill_value=0, margins=True, margins_name='total')

# Make a dict of the pivot table
spent = pivot.to_dict()

# Extract the value
boost_spent = spent["Boost"]["total"]
e_learning_spent = spent["eLearning"]["total"]
la_salle_spent = spent["LaSalle"]["total"]

spent
# Out:
# {'Boost': {'PO000000': 0.0,
#   'PO004623': 440.43,
#   'PO005153': 0.0,
#   'PO005154': 0.0,
#   'PO005283': 0.0,
#   'PO005379': 0.0,
#   'total': 440.43},
#  'eLearning': {'PO000000': 699.6,
#   'PO004623': 0.0,
#   'PO005153': 0.0,
#   'PO005154': 2848.27,
#   'PO005283': 0.0,
#   'PO005379': 0.0,
#   'total': 3547.87},
#  'laSalle': {'PO000000': 0.0,
#   'PO004623': 0.0,
#   'PO005153': 800.31,
#   'PO005154': 0.0,
#   'PO005283': 1267.4600000000003,
#   'PO005379': 61.8,
#   'total': 2129.57},
#  'total': {'PO000000': 699.6,
#   'PO004623': 440.43,
#   'PO005153': 800.31,
#   'PO005154': 2848.27,
#   'PO005283': 1267.4600000000003,
#   'PO005379': 61.8,
#   'total': 6117.869999999999}}

# %%
df.spend = df.spend.astype(int)
po_pivot = pd.pivot_table(df, values='spend', index=['po'], aggfunc=np.sum, fill_value=0)
po_pivot['spend'] = ": " + po_pivot['spend'].astype(str) + " $"
po_pivot
# Out:
#              spend
# po
# PO000000   : 696 $
# PO004623   : 439 $
# PO005153   : 793 $
# PO005154  : 2839 $
# PO005283  : 1254 $
# PO005379    : 60 $

# %%
# Out:
#               spend
# po
#  PO000000   : 696 $
#  PO004623   : 439 $
#  PO005153   : 793 $
#  PO005154  : 2839 $
#  PO005283  : 1254 $
#  PO005379    : 60 $

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-a1666f19f85a> in <module>
# ----> 1 PO000000
#
# NameError: name 'PO000000' is not defined

# %%
# Get date
today = datetime.today()
tday = today.strftime("%m-%d-%Y")

port = 465  # For SSL
password = os.environ.get("email_pdw")
context = ssl.create_default_context()
sender = os.environ.get("sender")
receiver = os.environ.get("receiver")

message = MIMEMultipart("alternative")
message["Subject"] = "Facebook Report " + str(tday)
message["From"] = sender
message["To"] = receiver

html = """
    <html>

    <head>
      <title> Facebook Report </title>
      <meta http-equiv='Content-Type' content='text/html; charset=UTF-8'>
      <meta name='viewport' content='width=device-width, initial-scale=1'>
      <style type='text/css'>
        # outlook a {
          padding: 0;
        }

        .ReadMsgBody {
          width: 100%;
        }

        .ExternalClass {
          width: 100%;
        }

        .ExternalClass * {
          line-height: 100%;
        }

        body {
          margin: 0;
          padding: 0;
          -webkit-text-size-adjust: 100%;
          -ms-text-size-adjust: 100%;
        }

        table,
        td {
          border-collapse: collapse;
          mso-table-lspace: 0pt;
          mso-table-rspace: 0pt;
        }

        img {
          border: 0;
          height: auto;
          line-height: 100%;
          outline: none;
          text-decoration: none;
          -ms-interpolation-mode: bicubic;
        }

        p {
          display: block;
          margin: 13px 0;
        }
      </style>

      <style type='text/css'>
        @media only screen and (min-width:480px) {
          .mj-column-per-60 {
            width: 60% !important;
            max-width: 60%;
          }

          .mj-column-per-40 {
            width: 40% !important;
            max-width: 40%;
          }

          .mj-column-per-100 {
            width: 100% !important;
            max-width: 100%;
          }

          .mj-column-per-45 {
            width: 45% !important;
            max-width: 45%;
          }

          .mj-column-per-11 {
            width: 11% !important;
            max-width: 11%;
          }

          .mj-column-per-89 {
            width: 89% !important;
            max-width: 89%;
          }

          .mj-column-per-75 {
            width: 75% !important;
            max-width: 75%;
          }

          .mj-column-per-25 {
            width: 25% !important;
            max-width: 25%;
          }

          .mj-column-per-65 {
            width: 65% !important;
            max-width: 65%;
          }

          .mj-column-per-35 {
            width: 35% !important;
            max-width: 35%;
          }
        }
      </style>
      <style type='text/css'>
        @media only screen and (max-width:480px) {
          table.full-width-mobile {
            width: 100% !important;
          }

          td.full-width-mobile {
            width: auto !important;
          }
        }
      </style>
    </head>

    <body>
      <div style=''>
        <div style='Margin:0px auto;max-width:600px;'>
          <table align='center' border='0' cellpadding='0' cellspacing='0' role='presentation' style='width:100%;'>
            <tbody>
              <tr>
                <td style='direction:ltr;font-size:0px;padding:20px 0;text-align:center;vertical-align:top;'>
                  <div class='mj-column-per-60 outlook-group-fix' style='font-size:13px;text-align:left;direction:ltr;display:inline-block;vertical-align:top;width:100%;'>
                    <table border='0' cellpadding='0' cellspacing='0' role='presentation' style='vertical-align:top;' width='100%'>
                    </table>
                  </div>
                  <div class='mj-column-per-40 outlook-group-fix' style='font-size:13px;text-align:left;direction:ltr;display:inline-block;vertical-align:top;width:100%;'>
                    <table border='0' cellpadding='0' cellspacing='0' role='presentation' style='vertical-align:top;' width='100%'>
                    </table>
                  </div>
                </td>
              </tr>
            </tbody>
          </table>
        </div>

        <div style='Margin:0px auto;max-width:600px;'>
          <table align='center' border='0' cellpadding='0' cellspacing='0' role='presentation' style='width:100%;'>
            <tbody>
              <tr>
                <td style='direction:ltr;font-size:0px;padding:0px;text-align:center;vertical-align:top;'>

                  <div class='mj-column-per-100 outlook-group-fix' style='font-size:13px;text-align:left;direction:ltr;display:inline-block;vertical-align:top;width:100%;'>
                    <table border='0' cellpadding='0' cellspacing='0' role='presentation' style='vertical-align:top;' width='100%'>
                      <tr>
                        <td align='center' style='font-size:0px;padding:10px 25px;word-break:break-word;'>
                          <table border='0' cellpadding='0' cellspacing='0' role='presentation' style='border-collapse:collapse;border-spacing:0px;'>
                            <tbody>
                              <tr>
                                <td style='width:550px;'>

                                  <img height='auto' src='https://www.lasallecollege.com/~/media/images/responsive/collegelasalle_montreal/home/visuel-page-accueil-2024x777_v3_en.ashx' style='border:0;display:block;outline:none;text-decoration:none;height:auto;width:100%;'
                                    width='550' />

                                </td>
                              </tr>
                            </tbody>
                          </table>
                        </td>
                      </tr>
                    </table>
                  </div>
                </td>
              </tr>
            </tbody>
          </table>
        </div>
        <div style='Margin:0px auto;max-width:600px;'>
          <table align='center' border='0' cellpadding='0' cellspacing='0' role='presentation' style='width:100%;'>
            <tbody>
              <tr>
                <td style='direction:ltr;font-size:0px;padding:0px;text-align:center;vertical-align:top;'>
                  <div class='mj-column-per-100 outlook-group-fix' style='font-size:13px;text-align:left;direction:ltr;display:inline-block;vertical-align:top;width:100%;'>
                    <table border='0' cellpadding='0' cellspacing='0' role='presentation' style='vertical-align:top;' width='100%'>
                      <tr>
                        <td align='center' style='font-size:0px;padding:10px 25px;word-break:break-word;'>
                          <div style='font-family:Roboto, Helvetica, sans-serif;font-size:16px;font-weight:300;line-height:24px;text-align:center;color:#616161;'> Your automated report is here! </div>
                        </td>
                      </tr>
                    </table>
                  </div>
                </td>
              </tr>
            </tbody>
          </table>
        </div>
        <div style='Margin:0px auto;max-width:600px;'>
          <table align='center' border='0' cellpadding='0' cellspacing='0' role='presentation' style='width:100%;'>
            <tbody>
              <tr>
                <td style='direction:ltr;font-size:0px;padding:0px;text-align:center;vertical-align:top;'>
                  <div class='mj-column-per-45 outlook-group-fix' style='font-size:13px;text-align:left;direction:ltr;display:inline-block;vertical-align:top;width:100%;'>
                    <table border='0' cellpadding='0' cellspacing='0' role='presentation' style='vertical-align:top;' width='100%'>
                      <tr>
                        <td align='center' style='font-size:0px;padding:0px;word-break:break-word;'>
                          <div style='font-family:Roboto, Helvetica, sans-serif;font-size:18px;font-weight:500;line-height:24px;text-align:center;color:#616161;'> FACEBOOK REPORT """ + str(tday) + """ </div>
                        </td>
                      </tr>
                      <tr>
                        <td style='font-size:0px;padding:10px 25px;word-break:break-word;'>
                          <p style='border-top:solid 2px #616161;font-size:1;margin:0px auto;width:100%;'> </p>
                        </td>
                      </tr>
                      <tr>
                        <td style='font-size:0px;padding:10px 25px;word-break:break-word;'>
                          <p style='border-top:solid 2px #616161;font-size:1;margin:0px auto;width:45%;'> </p>

                        </td>
                      </tr>
                    </table>
                  </div>

                </td>
              </tr>
            </tbody>
          </table>
        </div>

        <div style='Margin:0px auto;max-width:600px;'>
          <table align='center' border='0' cellpadding='0' cellspacing='0' role='presentation' style='width:100%;'>
            <tbody>
              <tr>
                <td style='direction:ltr;font-size:0px;padding:0px;padding-top:30px;text-align:center;vertical-align:top;'>

                  <div class='mj-column-per-100 outlook-group-fix' style='font-size:13px;text-align:left;direction:ltr;display:inline-block;vertical-align:top;width:100%;'>
                    <table border='0' cellpadding='0' cellspacing='0' role='presentation' style='vertical-align:top;' width='100%'>
                      <tr>
                        <td align='left' style='font-size:0px;padding:10px 25px;word-break:break-word;'>
                          <div style='font-family:Roboto, Helvetica, sans-serif;font-size:16px;font-weight:300;line-height:24px;text-align:left;color:#616161;'>
                            <p>Hey there!</p>
                            <p> Here are some key metrics from Facebook </p>

                            <p> Last week laSalle spent on Facebook was: """ + str(la_salle_spent) + """$
                              <br>
                              Last week laSalle boost spent on Facebook was: """ + str(boost_spent) + """$
                              <br>
                              Last week eLearning spent on Facebook was: """ + str(e_learning_spent) + """$
                              <br>
                              <br>
                              Spent per PO:
                              """ + tabulate(
        po_pivot, tablefmt='html') + """
                              <br>
                              </p>
                          </div>
                        </td>
                      </tr>
                    </table>
                  </div>

                </td>
              </tr>
            </tbody>
          </table>
        </div>
    """


part1 = MIMEText(html, "html")

message.attach(part1)

with smtplib.SMTP_SSL("smtp.gmail.com", port, context=context) as server:
    server.login(sender, password)
    server.sendmail(
    sender, receiver, message.as_string()
        )
