# %%
import os
import csv
import pandas as pd
import numpy as np
import ssl
import smtplib
import request
from dotenv import load_dotenv
from tabulate import tabulate
from datetime import datetime
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
from facebook_business.api import FacebookAdsApi
from facebook_business.adobjects.adaccount import AdAccount

# Load environement variables
load_dotenv()

path = os.getcwd()

# %%
# Getting Acces ID from env_vars
my_app_id = os.environ.get("MY_APP_ID")
my_app_secret = os.environ.get("MY_APP_SECRET")
my_access_token = os.environ.get("MY_ACCESS_TOKEN")

campus_name = "LaSalle"
# Initialitiong connection with Facebook
FacebookAdsApi.init(my_app_id, my_app_secret, my_access_token)

# Connecting to accounts
laSalle_account = AdAccount(os.environ.get("LASALLE_ACCOUNT"))

# Seting-Up my requests
params = {
    'date_preset': "last_week_mon_sun",
    "level": "campaign",
    'time_increment': "1"
}

fields = ["campaign_name", "reach", "clicks", "spend"]

# Requesting insights
campus_insights = laSalle_account.get_insights(params=params, fields=fields)

# Transform insights into a list of dict
campus_insights = [dict(x) for x in campus_insights]

# Print result
print(campus_insights)
# Out:
# [{'id': None, 'campaign_name': 'eLearning - Conversion - Budget Optimization - PO000000', 'reach': '6220', 'clicks': '86', 'spend': '100.7', 'date_start': '2019-04-08', 'date_stop': '2019-04-08'}, {'id': None, 'campaign_name': 'CLM - Conversion - Discussion DEC Phase 2 - Mars 2019 - FR - PO005153', 'reach': '8679', 'clicks': '59', 'spend': '63.24', 'date_start': '2019-04-08', 'date_stop': '2019-04-08'}, {'id': None, 'campaign_name': 'CLM - Conversion - Discussion DEC Phase 2 - Mars 2019 - EN - PO005153', 'reach': '10000', 'clicks': '42', 'spend': '51.1', 'date_start': '2019-04-08', 'date_stop': '2019-04-08'}, {'id': None, 'campaign_name': 'CLM - Rentrée été - Cuisine - EN/FR - PO005283', 'reach': '4027', 'clicks': '18', 'spend': '23.01', 'date_start': '2019-04-08', 'date_stop': '2019-04-08'}, {'id': None, 'campaign_name': 'CLM - Rentrée été 2019 - Mtl - FR - PO005283', 'reach': '5510', 'clicks': '59', 'spend': '60.3', 'date_start': '2019-04-08', 'date_stop': '2019-04-08'}, {'id': None, 'campaign_name': 'CLM - Rentrée été 2019 - Mtl - EN - PO005283', 'reach': '5878', 'clicks': '58', 'spend': '60.11', 'date_start': '2019-04-08', 'date_stop': '2019-04-08'}, {'id': None, 'campaign_name': 'CLM - Rentrée été 2019 - Laval - FR - PO005283', 'reach': '1955', 'clicks': '16', 'spend': '22.75', 'date_start': '2019-04-08', 'date_stop': '2019-04-08'}, {'id': None, 'campaign_name': 'CLM - Rentrée été 2019 - Laval - EN - PO005283', 'reach': '1479', 'clicks': '13', 'spend': '15.03', 'date_start': '2019-04-08', 'date_stop': '2019-04-08'}, {'id': None, 'campaign_name': 'eLearning - Rentrée été 2019 - FR - PO005154', 'reach': '7173', 'clicks': '90', 'spend': '106.65', 'date_start': '2019-04-08', 'date_stop': '2019-04-08'}, {'id': None, 'campaign_name': 'eLearning - Rentrée été 2019 - EN - PO005154', 'reach': '5080', 'clicks': '41', 'spend': '60.2', 'date_start': '2019-04-08', 'date_stop': '2019-04-08'}, {'id': None, 'campaign_name': 'eLearning- Webinaires - Avril 2019 - EN/FR - PO005154', 'reach': '11176', 'clicks': '182', 'spend': '283.18', 'date_start': '2019-04-08', 'date_stop': '2019-04-08'}, {'id': None, 'campaign_name': 'CLM - Signature 2019 -MTL - FR/En - PO005379', 'reach': '957', 'clicks': '1', 'spend': '17.13', 'date_start': '2019-04-08', 'date_stop': '2019-04-08'}, {'id': None, 'campaign_name': 'eLearning - Conversion - Budget Optimization - PO000000', 'reach': '6971', 'clicks': '73', 'spend': '97.25', 'date_start': '2019-04-09', 'date_stop': '2019-04-09'}, {'id': None, 'campaign_name': 'CLM - Conversion - Discussion DEC Phase 2 - Mars 2019 - FR - PO005153', 'reach': '6752', 'clicks': '46', 'spend': '58.55', 'date_start': '2019-04-09', 'date_stop': '2019-04-09'}, {'id': None, 'campaign_name': 'CLM - Conversion - Discussion DEC Phase 2 - Mars 2019 - EN - PO005153', 'reach': '9104', 'clicks': '46', 'spend': '46.67', 'date_start': '2019-04-09', 'date_stop': '2019-04-09'}, {'id': None, 'campaign_name': 'CLM - Rentrée été - Cuisine - EN/FR - PO005283', 'reach': '3601', 'clicks': '18', 'spend': '21.5', 'date_start': '2019-04-09', 'date_stop': '2019-04-09'}, {'id': None, 'campaign_name': 'CLM - Rentrée été 2019 - Mtl - FR - PO005283', 'reach': '4729', 'clicks': '47', 'spend': '56.7', 'date_start': '2019-04-09', 'date_stop': '2019-04-09'}, {'id': None, 'campaign_name': 'CLM - Rentrée été 2019 - Mtl - EN - PO005283', 'reach': '4794', 'clicks': '51', 'spend': '57.11', 'date_start': '2019-04-09', 'date_stop': '2019-04-09'}, {'id': None, 'campaign_name': 'CLM - Rentrée été 2019 - Laval - FR - PO005283', 'reach': '1878', 'clicks': '18', 'spend': '21.72', 'date_start': '2019-04-09', 'date_stop': '2019-04-09'}, {'id': None, 'campaign_name': 'CLM - Rentrée été 2019 - Laval - EN - PO005283', 'reach': '1226', 'clicks': '4', 'spend': '14.24', 'date_start': '2019-04-09', 'date_stop': '2019-04-09'}, {'id': None, 'campaign_name': 'eLearning - Rentrée été 2019 - FR - PO005154', 'reach': '6528', 'clicks': '95', 'spend': '99.45', 'date_start': '2019-04-09', 'd ...

# %%
# Create data frame
df = pd.DataFrame.from_dict(campus_insights)

# Format time
df = df.assign(Time=pd.to_datetime(df.date_stop))

# Remove unecessary columns
df = df.drop('date_start', axis='columns').drop('date_stop', axis='columns')

# Save data into csv file
df.to_csv(path + "\\" + campus_name + '_facebook_data.csv', index=False)

# %%
# Read scv
df = pd.read_csv(path + "\\" + campus_name + '_facebook_data.csv')
df
# Out:
#                                         campaign_name  clicks  id  reach  \
# 0   eLearning - Conversion - Budget Optimization -...      86 NaN   6220
# 1   CLM - Conversion - Discussion DEC Phase 2 - Ma...      59 NaN   8679
# 2   CLM - Conversion - Discussion DEC Phase 2 - Ma...      42 NaN  10000
# 3      CLM - Rentrée été - Cuisine - EN/FR - PO005283      18 NaN   4027
# 4        CLM - Rentrée été 2019 - Mtl - FR - PO005283      59 NaN   5510
# 5        CLM - Rentrée été 2019 - Mtl - EN - PO005283      58 NaN   5878
# 6      CLM - Rentrée été 2019 - Laval - FR - PO005283      16 NaN   1955
# 7      CLM - Rentrée été 2019 - Laval - EN - PO005283      13 NaN   1479
# 8        eLearning - Rentrée été 2019 - FR - PO005154      90 NaN   7173
# 9        eLearning - Rentrée été 2019 - EN - PO005154      41 NaN   5080
# 10  eLearning- Webinaires - Avril 2019 - EN/FR - P...     182 NaN  11176
# 11       CLM - Signature 2019 -MTL - FR/En - PO005379       1 NaN    957
# 12  eLearning - Conversion - Budget Optimization -...      73 NaN   6971
# 13  CLM - Conversion - Discussion DEC Phase 2 - Ma...      46 NaN   6752
# 14  CLM - Conversion - Discussion DEC Phase 2 - Ma...      46 NaN   9104
# 15     CLM - Rentrée été - Cuisine - EN/FR - PO005283      18 NaN   3601
# 16       CLM - Rentrée été 2019 - Mtl - FR - PO005283      47 NaN   4729
# 17       CLM - Rentrée été 2019 - Mtl - EN - PO005283      51 NaN   4794
# 18     CLM - Rentrée été 2019 - Laval - FR - PO005283      18 NaN   1878
# 19     CLM - Rentrée été 2019 - Laval - EN - PO005283       4 NaN   1226
# 20       eLearning - Rentrée été 2019 - FR - PO005154      95 NaN   6528
# 21       eLearning - Rentrée été 2019 - EN - PO005154      34 NaN   4084
# 22  eLearning- Webinaires - Avril 2019 - EN/FR - P...     172 NaN  10407
# 23       CLM - Signature 2019 -MTL - FR/En - PO005379       0 NaN    966
# 24  eLearning - Conversion - Budget Optimization -...      62 NaN   6141
# 25  CLM - Conversion - Discussion DEC Phase 2 - Ma...      32 NaN   6890
# 26  CLM - Conversion - Discussion DEC Phase 2 - Ma...      28 NaN  10166
# 27     CLM - Rentrée été - Cuisine - EN/FR - PO005283      12 NaN   3219
# 28       CLM - Rentrée été 2019 - Mtl - FR - PO005283      43 NaN   4706
# 29       CLM - Rentrée été 2019 - Mtl - EN - PO005283      45 NaN   4603
# ..                                                ...     ...  ..    ...
# 54     CLM - Rentrée été 2019 - Laval - FR - PO005283      13 NaN   1694
# 55     CLM - Rentrée été 2019 - Laval - EN - PO005283       9 NaN   1092
# 56       eLearning - Rentrée été 2019 - FR - PO005154      82 NaN   6686
# 57       eLearning - Rentrée été 2019 - EN - PO005154      27 NaN   4208
# 58  eLearning- Webinaires - Avril 2019 - EN/FR - P...     159 NaN  10098
# 59       CLM - Signature 2019 -MTL - FR/En - PO005379       4 NaN    932
# 60  eLearning - Conversion - Budget Optimization -...      70 NaN   7286
# 61  CLM - Conversion - Discussion DEC Phase 2 - Ma...      47 NaN   8160
# 62  CLM - Conversion - Discussion DEC Phase 2 - Ma...      44 NaN   9981
# 63     CLM - Rentrée été - Cuisine - EN/FR - PO005283      30 NaN   3900
# 64       CLM - Rentrée été 2019 - Mtl - FR - PO005283      61 NaN   5632
# 65       CLM - Rentrée été 2019 - Mtl - EN - PO005283      55 NaN   5356
# 66     CLM - Rentrée été 2019 - Laval - FR - PO005283       9 NaN   1833
# 67     CLM - Rentrée été 2019 - Laval - EN - PO005283      15 NaN   1243
# 68       eLearning - Rentrée été 2019 - FR - PO005154      72 NaN   7158
# 69       eLearning - Rentrée été 2019 - EN - PO005154      18 NaN   4953
# 70  eLearning- Webinaires - Avril 2019 - EN/FR - P...     131 NaN  10254
# 71       CLM - Signature 2019 -MTL - FR/En - PO005379       3 NaN    898
# 72  eLearning - Conversion - Budget Optimization -...      61 NaN   8662
# 73  CLM - Conversion - Discussion DEC Phase 2 - Ma...      26 NaN   4181
# 74  CLM - Conversion - Discussion DEC Phase 2 - Ma...      19 NaN   5766
# 75     CLM - Rentrée été - Cuisine - EN/FR - PO005283      10 NaN   4329
# 76       CLM - Rentrée été 2019 - Mtl - FR - PO005283      59 NaN   4763
# 77       CLM - Rentrée été 2019 - Mtl - EN - PO005283      46 NaN   4933
# 78     CLM - Rentrée été 2019 - Laval - FR - PO005283      18 NaN   1735
# 79     CLM - Rentrée été 2019 - Laval - EN - PO005283      11 NaN   1256
# 80       eLearning - Rentrée été 2019 - FR - PO005154      56 NaN   6543
# 81       eLearning - Rentrée été 2019 - EN - PO005154      25 NaN   4513
# 82  eLearning- Webinaires - Avril 2019 - EN/FR - P...     148 NaN   9724
# 83       CLM - Signature 2019 -MTL - FR/En - PO005379       4 NaN    884
#
#      spend        Time
# 0   100.70  2019-04-08
# 1    63.24  2019-04-08
# 2    51.10  2019-04-08
# 3    23.01  2019-04-08
# 4    60.30  2019-04-08
# 5    60.11  2019-04-08
# 6    22.75  2019-04-08
# 7    15.03  2019-04-08
# 8   106.65  2019-04-08
# 9    60.20  2019-04-08
# 10  283.18  2019-04-08
# 11   17.13  2019-04-08
# 12   97.25  2019-04-09
# 13   58.55  2019-04-09
# 14   46.67  2019-04-09
# 15   21.50  2019-04-09
# 16   56.70  2019-04-09
# 17   57.11  2019-04-09
# 18   21.72  2019-04-09
# 19   14.24  2019-04-09
# 20   99.45  2019-04-09
# 21   56.18  2019-04-09
# 22  260.55  2019-04-09
# 23   17.90  2019-04-09
# 24   96.18  2019-04-10
# 25   59.05  2019-04-10
# 26   48.06  2019-04-10
# 27   21.53  2019-04-10
# 28   57.16  2019-04-10
# 29   57.17  2019-04-10
# ..     ...         ...
# 54   23.71  2019-04-12
# 55   14.73  2019-04-12
# 56  105.99  2019-04-12
# 57   60.23  2019-04-12
# 58  267.10  2019-04-12
# 59   17.58  2019-04-12
# 60  109.95  2019-04-13
# 61   65.87  2019-04-13
# 62   52.34  2019-04-13
# 63   23.79  2019-04-13
# 64   63.00  2019-04-13
# 65   61.99  2019-04-13
# 66   23.25  2019-04-13
# 67   15.87  2019-04-13
# 68  114.30  2019-04-13
# 69   63.66  2019-04-13
# 70  262.40  2019-04-13
# 71   17.40  2019-04-13
# 72   99.03  2019-04-14
# 73   32.10  2019-04-14
# 74   25.98  2019-04-14
# 75   21.15  2019-04-14
# 76   55.01  2019-04-14
# 77   55.12  2019-04-14
# 78   21.38  2019-04-14
# 79   13.85  2019-04-14
# 80   97.01  2019-04-14
# 81   54.58  2019-04-14
# 82  269.53  2019-04-14
# 83   16.85  2019-04-14
#
# [84 rows x 6 columns]

# %%
# Identify schools and boost
if campus_name == "LaSalle":
    df['campaign_name'] = df['campaign_name'].str.replace(
        "CLM", "LaSalle").str.replace(
        "CL", "Boost").str.replace(
        "eLearning ", "eLearning")

elif campus_name == "InterDec":
    df['campaign_name'] = df['campaign_name'].str.replace(
        "CID", "InterDec")

else:
    df['campaign_name'] = campus_name + "-" + df['campaign_name'].astype(str)


# Create school column
df['school'] = df["campaign_name"].str.split("-", n=1, expand=True)[0]
df['school'] = df['school'].str.replace(" ", "")

# Intermediate state to get a clean campaign column
df["campaign_rename"] = df["campaign_name"].str.split(
    "-", n=1, expand=True)[1]

if campus_name == "LaSalle" or campus_name == "InterDec":
    # Create PO column
    df["po"] = df["campaign_rename"].str.rsplit("-", n=1, expand=True)[1]
    df["po"] = df["po"].str.replace(" ", "")

# Create a clean campaign column
df["campaign"] = df["campaign_rename"].str.rsplit("-", n=1, expand=True)[0]

# Get rid of dirty columns
df = df.drop(
        'campaign_name', axis='columns').drop(
        'campaign_rename', axis='columns')

# Reorder columns
if campus_name == "LaSalle" or campus_name == "InterDec":
    clean = df[["campaign",
                    "school",
                    "po",
                    "Time",
                    "spend",
                    "reach",
                    "clicks"]]
else:
    clean = df[["campaign",
                    "school",
                    "Time",
                    "spend",
                    "reach",
                    "clicks"]]

clean.to_csv(path + "\\" + campus_name + '_facebook_data_cleaned.csv',
             header=True, index=False, index_label=False)
clean
# Out:
#                                              campaign     school        po  \
# 0                   Conversion - Budget Optimization   eLearning  PO000000
# 1    Conversion - Discussion DEC Phase 2 - Mars 20...    LaSalle  PO005153
# 2    Conversion - Discussion DEC Phase 2 - Mars 20...    LaSalle  PO005153
# 3                      Rentrée été - Cuisine - EN/FR     LaSalle  PO005283
# 4                        Rentrée été 2019 - Mtl - FR     LaSalle  PO005283
# 5                        Rentrée été 2019 - Mtl - EN     LaSalle  PO005283
# 6                      Rentrée été 2019 - Laval - FR     LaSalle  PO005283
# 7                      Rentrée été 2019 - Laval - EN     LaSalle  PO005283
# 8                              Rentrée été 2019 - FR   eLearning  PO005154
# 9                              Rentrée été 2019 - EN   eLearning  PO005154
# 10                   Webinaires - Avril 2019 - EN/FR   eLearning  PO005154
# 11                       Signature 2019 -MTL - FR/En     LaSalle  PO005379
# 12                  Conversion - Budget Optimization   eLearning  PO000000
# 13   Conversion - Discussion DEC Phase 2 - Mars 20...    LaSalle  PO005153
# 14   Conversion - Discussion DEC Phase 2 - Mars 20...    LaSalle  PO005153
# 15                     Rentrée été - Cuisine - EN/FR     LaSalle  PO005283
# 16                       Rentrée été 2019 - Mtl - FR     LaSalle  PO005283
# 17                       Rentrée été 2019 - Mtl - EN     LaSalle  PO005283
# 18                     Rentrée été 2019 - Laval - FR     LaSalle  PO005283
# 19                     Rentrée été 2019 - Laval - EN     LaSalle  PO005283
# 20                             Rentrée été 2019 - FR   eLearning  PO005154
# 21                             Rentrée été 2019 - EN   eLearning  PO005154
# 22                   Webinaires - Avril 2019 - EN/FR   eLearning  PO005154
# 23                       Signature 2019 -MTL - FR/En     LaSalle  PO005379
# 24                  Conversion - Budget Optimization   eLearning  PO000000
# 25   Conversion - Discussion DEC Phase 2 - Mars 20...    LaSalle  PO005153
# 26   Conversion - Discussion DEC Phase 2 - Mars 20...    LaSalle  PO005153
# 27                     Rentrée été - Cuisine - EN/FR     LaSalle  PO005283
# 28                       Rentrée été 2019 - Mtl - FR     LaSalle  PO005283
# 29                       Rentrée été 2019 - Mtl - EN     LaSalle  PO005283
# ..                                                ...        ...       ...
# 54                     Rentrée été 2019 - Laval - FR     LaSalle  PO005283
# 55                     Rentrée été 2019 - Laval - EN     LaSalle  PO005283
# 56                             Rentrée été 2019 - FR   eLearning  PO005154
# 57                             Rentrée été 2019 - EN   eLearning  PO005154
# 58                   Webinaires - Avril 2019 - EN/FR   eLearning  PO005154
# 59                       Signature 2019 -MTL - FR/En     LaSalle  PO005379
# 60                  Conversion - Budget Optimization   eLearning  PO000000
# 61   Conversion - Discussion DEC Phase 2 - Mars 20...    LaSalle  PO005153
# 62   Conversion - Discussion DEC Phase 2 - Mars 20...    LaSalle  PO005153
# 63                     Rentrée été - Cuisine - EN/FR     LaSalle  PO005283
# 64                       Rentrée été 2019 - Mtl - FR     LaSalle  PO005283
# 65                       Rentrée été 2019 - Mtl - EN     LaSalle  PO005283
# 66                     Rentrée été 2019 - Laval - FR     LaSalle  PO005283
# 67                     Rentrée été 2019 - Laval - EN     LaSalle  PO005283
# 68                             Rentrée été 2019 - FR   eLearning  PO005154
# 69                             Rentrée été 2019 - EN   eLearning  PO005154
# 70                   Webinaires - Avril 2019 - EN/FR   eLearning  PO005154
# 71                       Signature 2019 -MTL - FR/En     LaSalle  PO005379
# 72                  Conversion - Budget Optimization   eLearning  PO000000
# 73   Conversion - Discussion DEC Phase 2 - Mars 20...    LaSalle  PO005153
# 74   Conversion - Discussion DEC Phase 2 - Mars 20...    LaSalle  PO005153
# 75                     Rentrée été - Cuisine - EN/FR     LaSalle  PO005283
# 76                       Rentrée été 2019 - Mtl - FR     LaSalle  PO005283
# 77                       Rentrée été 2019 - Mtl - EN     LaSalle  PO005283
# 78                     Rentrée été 2019 - Laval - FR     LaSalle  PO005283
# 79                     Rentrée été 2019 - Laval - EN     LaSalle  PO005283
# 80                             Rentrée été 2019 - FR   eLearning  PO005154
# 81                             Rentrée été 2019 - EN   eLearning  PO005154
# 82                   Webinaires - Avril 2019 - EN/FR   eLearning  PO005154
# 83                       Signature 2019 -MTL - FR/En     LaSalle  PO005379
#
#           Time   spend  reach  clicks
# 0   2019-04-08  100.70   6220      86
# 1   2019-04-08   63.24   8679      59
# 2   2019-04-08   51.10  10000      42
# 3   2019-04-08   23.01   4027      18
# 4   2019-04-08   60.30   5510      59
# 5   2019-04-08   60.11   5878      58
# 6   2019-04-08   22.75   1955      16
# 7   2019-04-08   15.03   1479      13
# 8   2019-04-08  106.65   7173      90
# 9   2019-04-08   60.20   5080      41
# 10  2019-04-08  283.18  11176     182
# 11  2019-04-08   17.13    957       1
# 12  2019-04-09   97.25   6971      73
# 13  2019-04-09   58.55   6752      46
# 14  2019-04-09   46.67   9104      46
# 15  2019-04-09   21.50   3601      18
# 16  2019-04-09   56.70   4729      47
# 17  2019-04-09   57.11   4794      51
# 18  2019-04-09   21.72   1878      18
# 19  2019-04-09   14.24   1226       4
# 20  2019-04-09   99.45   6528      95
# 21  2019-04-09   56.18   4084      34
# 22  2019-04-09  260.55  10407     172
# 23  2019-04-09   17.90    966       0
# 24  2019-04-10   96.18   6141      62
# 25  2019-04-10   59.05   6890      32
# 26  2019-04-10   48.06  10166      28
# 27  2019-04-10   21.53   3219      12
# 28  2019-04-10   57.16   4706      43
# 29  2019-04-10   57.17   4603      45
# ..         ...     ...    ...     ...
# 54  2019-04-12   23.71   1694      13
# 55  2019-04-12   14.73   1092       9
# 56  2019-04-12  105.99   6686      82
# 57  2019-04-12   60.23   4208      27
# 58  2019-04-12  267.10  10098     159
# 59  2019-04-12   17.58    932       4
# 60  2019-04-13  109.95   7286      70
# 61  2019-04-13   65.87   8160      47
# 62  2019-04-13   52.34   9981      44
# 63  2019-04-13   23.79   3900      30
# 64  2019-04-13   63.00   5632      61
# 65  2019-04-13   61.99   5356      55
# 66  2019-04-13   23.25   1833       9
# 67  2019-04-13   15.87   1243      15
# 68  2019-04-13  114.30   7158      72
# 69  2019-04-13   63.66   4953      18
# 70  2019-04-13  262.40  10254     131
# 71  2019-04-13   17.40    898       3
# 72  2019-04-14   99.03   8662      61
# 73  2019-04-14   32.10   4181      26
# 74  2019-04-14   25.98   5766      19
# 75  2019-04-14   21.15   4329      10
# 76  2019-04-14   55.01   4763      59
# 77  2019-04-14   55.12   4933      46
# 78  2019-04-14   21.38   1735      18
# 79  2019-04-14   13.85   1256      11
# 80  2019-04-14   97.01   6543      56
# 81  2019-04-14   54.58   4513      25
# 82  2019-04-14  269.53   9724     148
# 83  2019-04-14   16.85    884       4
#
# [84 rows x 7 columns]

# %%
df = pd.read_csv(path + "\\" + campus_name + '_facebook_data_cleaned.csv')
df
# Out:
#                                              campaign     school        po  \
# 0                   Campagne permanente - Boost post       Boost  PO004623
# 1                   Conversion - Budget Optimization   eLearning  PO000000
# 2    Conversion - Discussion DEC Phase 2 - Mars 20...    LaSalle  PO005153
# 3    Conversion - Discussion DEC Phase 2 - Mars 20...    LaSalle  PO005153
# 4                      Rentrée été - Cuisine - EN/FR     LaSalle  PO005283
# 5                        Rentrée été 2019 - Mtl - FR     LaSalle  PO005283
# 6                        Rentrée été 2019 - Mtl - EN     LaSalle  PO005283
# 7                      Rentrée été 2019 - Laval - FR     LaSalle  PO005283
# 8                      Rentrée été 2019 - Laval - EN     LaSalle  PO005283
# 9                              Rentrée été 2019 - FR   eLearning  PO005154
# 10                             Rentrée été 2019 - EN   eLearning  PO005154
# 11                   Webinaires - Avril 2019 - EN/FR   eLearning  PO005154
# 12                  Campagne permanente - Boost post       Boost  PO004623
# 13                  Conversion - Budget Optimization   eLearning  PO000000
# 14   Conversion - Discussion DEC Phase 2 - Mars 20...    LaSalle  PO005153
# 15   Conversion - Discussion DEC Phase 2 - Mars 20...    LaSalle  PO005153
# 16                     Rentrée été - Cuisine - EN/FR     LaSalle  PO005283
# 17                       Rentrée été 2019 - Mtl - FR     LaSalle  PO005283
# 18                       Rentrée été 2019 - Mtl - EN     LaSalle  PO005283
# 19                     Rentrée été 2019 - Laval - FR     LaSalle  PO005283
# 20                     Rentrée été 2019 - Laval - EN     LaSalle  PO005283
# 21                             Rentrée été 2019 - FR   eLearning  PO005154
# 22                             Rentrée été 2019 - EN   eLearning  PO005154
# 23                   Webinaires - Avril 2019 - EN/FR   eLearning  PO005154
# 24                  Campagne permanente - Boost post       Boost  PO004623
# 25                  Conversion - Budget Optimization   eLearning  PO000000
# 26   Conversion - Discussion DEC Phase 2 - Mars 20...    LaSalle  PO005153
# 27   Conversion - Discussion DEC Phase 2 - Mars 20...    LaSalle  PO005153
# 28                     Rentrée été - Cuisine - EN/FR     LaSalle  PO005283
# 29                       Rentrée été 2019 - Mtl - FR     LaSalle  PO005283
# ..                                                ...        ...       ...
# 54                     Rentrée été 2019 - Laval - FR     LaSalle  PO005283
# 55                     Rentrée été 2019 - Laval - EN     LaSalle  PO005283
# 56                             Rentrée été 2019 - FR   eLearning  PO005154
# 57                             Rentrée été 2019 - EN   eLearning  PO005154
# 58                   Webinaires - Avril 2019 - EN/FR   eLearning  PO005154
# 59                       Signature 2019 -MTL - FR/En     LaSalle  PO005379
# 60                  Conversion - Budget Optimization   eLearning  PO000000
# 61   Conversion - Discussion DEC Phase 2 - Mars 20...    LaSalle  PO005153
# 62   Conversion - Discussion DEC Phase 2 - Mars 20...    LaSalle  PO005153
# 63                     Rentrée été - Cuisine - EN/FR     LaSalle  PO005283
# 64                       Rentrée été 2019 - Mtl - FR     LaSalle  PO005283
# 65                       Rentrée été 2019 - Mtl - EN     LaSalle  PO005283
# 66                     Rentrée été 2019 - Laval - FR     LaSalle  PO005283
# 67                     Rentrée été 2019 - Laval - EN     LaSalle  PO005283
# 68                             Rentrée été 2019 - FR   eLearning  PO005154
# 69                             Rentrée été 2019 - EN   eLearning  PO005154
# 70                   Webinaires - Avril 2019 - EN/FR   eLearning  PO005154
# 71                       Signature 2019 -MTL - FR/En     LaSalle  PO005379
# 72                  Conversion - Budget Optimization   eLearning  PO000000
# 73   Conversion - Discussion DEC Phase 2 - Mars 20...    LaSalle  PO005153
# 74   Conversion - Discussion DEC Phase 2 - Mars 20...    LaSalle  PO005153
# 75                     Rentrée été - Cuisine - EN/FR     LaSalle  PO005283
# 76                       Rentrée été 2019 - Mtl - FR     LaSalle  PO005283
# 77                       Rentrée été 2019 - Mtl - EN     LaSalle  PO005283
# 78                     Rentrée été 2019 - Laval - FR     LaSalle  PO005283
# 79                     Rentrée été 2019 - Laval - EN     LaSalle  PO005283
# 80                             Rentrée été 2019 - FR   eLearning  PO005154
# 81                             Rentrée été 2019 - EN   eLearning  PO005154
# 82                   Webinaires - Avril 2019 - EN/FR   eLearning  PO005154
# 83                       Signature 2019 -MTL - FR/En     LaSalle  PO005379
#
#           Time   spend  reach  clicks
# 0   2019-04-01  172.24  18251    2282
# 1   2019-04-01   97.93   5898      73
# 2   2019-04-01   65.08   7588      61
# 3   2019-04-01   51.40   7744      35
# 4   2019-04-01   23.24   4090      17
# 5   2019-04-01   60.20   4911      50
# 6   2019-04-01   60.52   5161      60
# 7   2019-04-01   23.36   1901      23
# 8   2019-04-01   15.16   1295       9
# 9   2019-04-01  106.60   6616     102
# 10  2019-04-01   60.43   4501      29
# 11  2019-04-01  193.37   8890     195
# 12  2019-04-02  173.45  25677    4329
# 13  2019-04-02  101.44   7103      82
# 14  2019-04-02   63.98   6106      61
# 15  2019-04-02   51.38   9583      43
# 16  2019-04-02   22.97   4324      18
# 17  2019-04-02   60.46   5036      66
# 18  2019-04-02   59.88   5836      58
# 19  2019-04-02   22.87   1841      18
# 20  2019-04-02   14.68   1385      11
# 21  2019-04-02  104.09   6654      98
# 22  2019-04-02   58.75   4289      25
# 23  2019-04-02  277.09  11380     287
# 24  2019-04-03   94.74  16679    2971
# 25  2019-04-03   96.81   7118      72
# 26  2019-04-03   60.22   7664      77
# 27  2019-04-03   48.54  10612      37
# 28  2019-04-03   22.15   3686      17
# 29  2019-04-03   57.25   4921      52
# ..         ...     ...    ...     ...
# 54  2019-04-05   22.20   1980      22
# 55  2019-04-05   14.61   1331       4
# 56  2019-04-05  106.01   7026     111
# 57  2019-04-05   60.41   4356      22
# 58  2019-04-05  211.40   7792     129
# 59  2019-04-05   16.09    909       7
# 60  2019-04-06  111.43   8195      84
# 61  2019-04-06   65.93   6620      49
# 62  2019-04-06   53.83  11012      56
# 63  2019-04-06   24.12   3619      18
# 64  2019-04-06   63.00   4698      56
# 65  2019-04-06   63.99   4973      49
# 66  2019-04-06   24.70   1906      16
# 67  2019-04-06   16.60   1364       3
# 68  2019-04-06  116.17   7042     109
# 69  2019-04-06   65.10   4441      34
# 70  2019-04-06  239.98   8834     126
# 71  2019-04-06   17.62    969       5
# 72  2019-04-07   96.21   6193      53
# 73  2019-04-07   62.29   8606      54
# 74  2019-04-07   51.08  10632      45
# 75  2019-04-07   23.15   3608      20
# 76  2019-04-07   60.40   4965      66
# 77  2019-04-07   61.02   5350      63
# 78  2019-04-07   23.27   1885      15
# 79  2019-04-07   15.26   1226      10
# 80  2019-04-07  106.11   6218      88
# 81  2019-04-07   60.44   4370      26
# 82  2019-04-07  267.93   9824     163
# 83  2019-04-07   17.94   1046       0
#
# [84 rows x 7 columns]

# %%
# Make sure spend is the right data type
df.spend = df.spend.astype(int)

# Create pivot table to extract some KPI
pivot = pd.pivot_table(
    df, values='spend', index=['school'], aggfunc=np.sum, fill_value=0,).reset_index()

# format
pivot['spend'] = ": " + pivot['spend'].astype(str) + "$"

pivot.to_csv(path + "\\" + campus_name + '_facebook_data_calculated.csv',
                 header=True, index=False, index_label=False)
    
# Calculate spent for Mtl campus
if campus_name == "InterDec" or campus_name == "LaSalle":
    
    # Create a new pivot table for per PO breakdown
    po_pivot = pd.pivot_table(df, values='spend',
                                  index=['po'], aggfunc=np.sum, fill_value=0).reset_index()
    
    po_pivot.columns = ["school", "spend"]

    # Format it
    po_pivot['spend'] = ": " + po_pivot['spend'].astype(str) + "$"

    po_pivot.to_csv(path + "\\" + campus_name + '_facebook_data_po_calculated.csv',
                 header=True, index=False, index_label=False)
    
po_pivot
# Out:
#      school    spend
# 0  PO000000   : 700$
# 1  PO005153   : 737$
# 2  PO005154  : 2996$
# 3  PO005283  : 1236$
# 4  PO005379   : 117$

# %%
# Out:
#                            spend
# po
# PO000000               : 699.6 $
# PO004623              : 440.43 $
# PO005153              : 800.31 $
# PO005154             : 2848.27 $
# PO005283  : 1267.4600000000003 $
# PO005379                : 61.8 $
